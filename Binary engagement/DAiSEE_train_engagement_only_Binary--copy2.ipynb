# %%
# === Imports === #

import tensorflow as tf
from tensorflow.keras.models import load_model

from tqdm import tqdm

# Various python packages are used in this notebook. Please get yourself used to them (optional).
import pandas as pd  # used for storing a tabular representation of the dataset, similar to XLS files.
from pathlib import Path # used to check if the saved model files and accessories.
import requests #used to request remote judge.csv evaluation 
from sklearn.preprocessing import StandardScaler  # used for normalization of dataset
from sklearn.preprocessing   import LabelBinarizer    # used for splitting the gender column
from sklearn.preprocessing   import MinMaxScaler      # used for normalization of dataset
from sklearn.model_selection import train_test_split  # used for performing the train-test split of a dataframe
import cv2                                            # OpenCV used for image processing
import random   #random number generator
import datetime #used to get current date/time
import math     #math/numerical functions
import os       #os specific functions, like file open/close etc.
import gc       #garbage collection module -- used to manually clean up memory spaces/references.


from sklearn.preprocessing import OneHotEncoder   #My favorite categorical to numerical feature conversion tool
from tensorflow import keras  # keras used for construction of the Artificial neural network
from keras.models import Model, Sequential #keras model architectures
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D #types of layers
from keras.losses import mean_squared_error, huber, log_cosh  #built-in loss 
from tensorflow.python.keras.saving import hdf5_format  #used for saving models 
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard  #callbacks
from keras.models import model_from_json  #used for loading model architecture from json file
import h5py  #saved model type

import matplotlib.pyplot as plt  # used for training visualization
import numpy as np  # numpy arrays used for matrix computations

# === Extra Configurations for the GPU Environment === #
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
if len(physical_devices)>0: #If you have at least one "configured" GPU, let's use it; otherwise, pass
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# https://github.com/zaid478/Transfer-Learning-from-Xception-Model-in-Keras-/blob/master/transfer_learn.py

from keras.applications import xception
from keras import backend as K
from keras.utils import np_utils

from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

# %%
"""
Setting work environment with dataset. If on Google colaboratory, we need to extract dataset stored in google drive,
otherwise the dataset is already there.
"""
try:
    from google.colab import drive
    print('Running on Google colab...')
    drive.mount('/content/drive')
except:
    print('Running on local machine...')
# Out:
# Running on Google colab...
# Mounted at /content/drive

# %% [markdown]
# # IMPORTANT VARIABLES

# %%
train_path = 'drive/MyDrive/Colab Notebooks/DAiSEE/gen-full-4/Train/'
test_path = 'drive/MyDrive/Colab Notebooks/DAiSEE/gen-full-4/Test/'

image_shape = (224, 299, 3) # HEIGHT, WIDTH, CHANNELS

# %% [markdown]
# # Train a new Xception model

# %%
xception_tl = tf.keras.applications.Xception(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=image_shape,
    pooling=None,
    classes=2,
    classifier_activation="softmax",
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step
# 83697664/83683744 [==============================] - 0s 0us/step

# %%
for layer in xception_tl.layers:
	layer.trainable=False

# %%
x = xception_tl.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu', name='learning_layer')(x)
y1 = Dense(2, activation='softmax', name='y1')(x)

xception_tl_DAiSEE=Model(xception_tl.input, y1)

# %%
xception_tl_DAiSEE.output
# Out:
# <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'y1')>

# %% [markdown]
# https://stanford.edu/~shervine/blog/keras-how-to-generate-data-on-the-fly

# %%
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, path, list_IDs, labels, batch_size=32, dim=(480,640), n_channels=3,
                 n_classes=4, shuffle=True):
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.list_IDs = list_IDs
        self.path = path
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(indexes)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((self.batch_size, *self.dim, self.n_channels))
        y = np.empty((self.batch_size, self.n_classes), dtype='float32')

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            filename = os.path.join(self.path, self.list_IDs[ID])
            x = cv2.imread(filename)
            X[i,] = tf.keras.applications.xception.preprocess_input(x)
            #y[i,:] = tf.one_hot(self.labels[ID][1], depth=4)
            y[i,:] = tf.one_hot(self.labels[ID][1]>=2, depth=2) # binary classification

        return X, tf.convert_to_tensor(y)

# %%
'''
import numpy as np
y = [3, 2, 1, 2, 3, 1, 0, 0 ,1]
y = [1 if  i>=2 else 0 for i in y]
print(y)
'''
# Out:
# '\nimport numpy as np\ny = [3, 2, 1, 2, 3, 1, 0, 0 ,1]\ny = [1 if  i>=2 else 0 for i in y]\nprint(y)\n'

# %%
'''
Alternative method for loading the dataset via tar file
'''

import os
import shutil
import tarfile

tar_name = 'gen-full-4.tar'
tar_path = 'drive/MyDrive/Colab Notebooks/DAiSEE/' + tar_name

temp_data_location = 'temp_data'

if temp_data_location in os.listdir(os.getcwd()):
    shutil.rmtree(temp_data_location)

os.mkdir(temp_data_location)

shutil.copyfile(tar_path, os.path.join('/content/', tar_name)) 

tar = tarfile.open(os.path.join('/content/', tar_name)) 
tar.extractall(path=temp_data_location)
tar.close()

# %%
local_train_path = os.path.join(temp_data_location, 'Train')
local_test_path = os.path.join(temp_data_location, 'Test')

# %%
#shutil.copyfile(tar_path, os.path.join('/content/', tar_name))

# %%
'''

import os
import shutil
#os.getcwd()

temp_data_location = 'temp_data'

if temp_data_location in os.listdir(os.getcwd()):
    shutil.rmtree(temp_data_location)

os.mkdir(temp_data_location)

#assert temp_data_location not in os.listdir(os.getcwd())


local_train_path = os.path.join(temp_data_location, 'Train')
local_test_path = os.path.join(temp_data_location, 'Test') 

# Copytree makes the folders
#os.mkdir(local_train_path)
#os.mkdir(local_test_path)

shutil.copytree(train_path, local_train_path) 
shutil.copytree(test_path, local_test_path)
'''
# Out:
# "\n\nimport os\nimport shutil\n#os.getcwd()\n\ntemp_data_location = 'temp_data'\n\nif temp_data_location in os.listdir(os.getcwd()):\n    shutil.rmtree(temp_data_location)\n\nos.mkdir(temp_data_location)\n\n#assert temp_data_location not in os.listdir(os.getcwd())\n\n\nlocal_train_path = os.path.join(temp_data_location, 'Train')\nlocal_test_path = os.path.join(temp_data_location, 'Test') \n\n# Copytree makes the folders\n#os.mkdir(local_train_path)\n#os.mkdir(local_test_path)\n\nshutil.copytree(train_path, local_train_path) \nshutil.copytree(test_path, local_test_path)\n"

# %%
# temp solution
#shutil.copytree(local_train_path, local_test_path)

# %%
# Generator Parameters
params = {'dim': (image_shape[0], image_shape[1]),
          'batch_size': 64,
          'n_classes': 2,
          'n_channels': 3,
          'shuffle': True}

folder_path = './drive/MyDrive/Colab Notebooks/DAiSEE/'
all_labels = pd.read_csv(os.path.join(folder_path, 'Labels/AllLabels.csv'))
all_labels['ID_num'] = all_labels['ClipID'].str[:-4]

train_labels = pd.read_csv(os.path.join(folder_path, 'Labels/TrainLabels.csv'))
train_labels['ID_num'] = train_labels['ClipID'].str[:-4]

test_labels = pd.read_csv(os.path.join(folder_path, 'Labels/TestLabels.csv'))
test_labels['ID_num'] = test_labels['ClipID'].str[:-4]

# Train Set
file_labels = []
print("building train set")
for filename in tqdm(os.listdir(local_train_path)):
    try:
        sample_ID = filename[:filename.index('-')]
        label = all_labels[all_labels['ID_num']==sample_ID].values.tolist()[0][1:-1]
        file_labels.append((filename, np.array(label)))
    except IndexError:
        #print(sample_ID)
        pass

label_arr = np.array(file_labels, dtype=object)
X_train = label_arr[:, 0]
y_train = label_arr[:, 1]

# Test Set
file_labels = []
print("building test set")
for filename in tqdm(os.listdir(local_test_path)):
    try:
        sample_ID = filename[:filename.index('-')]
        label = all_labels[all_labels['ID_num']==sample_ID].values.tolist()[0][1:-1]
        #label = test_labels[test_labels['ID_num']==sample_ID].values.tolist()[0][1:-1]
        file_labels.append((filename, np.array(label)))
    except IndexError:
        #print(sample_ID)
        pass

label_arr = np.array(file_labels, dtype=object)
X_test = label_arr[:, 0]
y_test = label_arr[:, 1]
# Out:
# building train set
# 100%|██████████| 38374/38374 [00:39<00:00, 972.75it/s]
# building test set
# 100%|██████████| 13062/13062 [00:13<00:00, 1003.95it/s]

# %%
y_test
# Out:
# array([array([0, 3, 0, 0]), array([2, 2, 1, 1]), array([1, 2, 0, 0]), ...,
#        array([2, 2, 0, 1]), array([1, 1, 0, 0]), array([0, 3, 0, 0])],
#       dtype=object)

# %%
y_test.shape
# Out:
# (12061,)

# %%
# Generators
training_generator = DataGenerator(local_train_path, X_train, y_train, **params)
validation_generator = DataGenerator(local_test_path, X_test, y_test, **params)

# %%
'''
class_weight = {0: 75.,
                1: 10.,
                2: 1.,
                3: 1.}

class_weight = {0: 1.,
                1: 1.,
                2: 1.,
                3: 1.}
'''

#class_weight = {0: 2., 1: 1.}
class_weight = {0: 1., 1: 1.}

# %%
# %reload_ext tensorboard
model_path = os.path.join(folder_path, 'saved_models/model_' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '_.sav')
log_dir = os.path.join(folder_path, "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

tensorboard_cbk = TensorBoard(log_dir=log_dir, histogram_freq=1)
early_stopping_cbk = EarlyStopping(monitor='val_accuracy', patience=10, verbose=0, mode='min')
mcp_save_cbk = ModelCheckpoint(model_path+'.mcp.hdf5', save_best_only=True, monitor='val_accuracy', mode='min')
reduce_lr_plateau_cbk = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, mode='min')
#callbacks = [early_stopping_cbk, mcp_save_cbk, reduce_lr_plateau_cbk, tensorboard_cbk]
callbacks = [mcp_save_cbk, reduce_lr_plateau_cbk, tensorboard_cbk]

# %%
xception_tl_DAiSEE.compile(loss = 'binary_crossentropy', optimizer='adam',
                         metrics = ['cosine_similarity', 'mean_absolute_error', 'accuracy'])

# %%
history = xception_tl_DAiSEE.fit(training_generator, validation_data=validation_generator, class_weight=class_weight, batch_size=64, epochs=50, callbacks=callbacks)
# Out:
# Epoch 1/50
# 599/599 [==============================] - 290s 465ms/step - loss: 0.1697 - cosine_similarity: 0.9553 - mean_absolute_error: 0.0502 - accuracy: 0.9536 - val_loss: 0.2206 - val_cosine_similarity: 0.9507 - val_mean_absolute_error: 0.0655 - val_accuracy: 0.9507 - lr: 0.0010
# Epoch 2/50
# 599/599 [==============================] - 278s 464ms/step - loss: 0.1531 - cosine_similarity: 0.9570 - mean_absolute_error: 0.0497 - accuracy: 0.9548 - val_loss: 0.2195 - val_cosine_similarity: 0.9508 - val_mean_absolute_error: 0.0530 - val_accuracy: 0.9507 - lr: 0.0010
# Epoch 3/50
# 599/599 [==============================] - 275s 459ms/step - loss: 0.1449 - cosine_similarity: 0.9580 - mean_absolute_error: 0.0491 - accuracy: 0.9548 - val_loss: 0.2433 - val_cosine_similarity: 0.9505 - val_mean_absolute_error: 0.0622 - val_accuracy: 0.9507 - lr: 0.0010
# Epoch 4/50
# 599/599 [==============================] - 276s 461ms/step - loss: 0.1391 - cosine_similarity: 0.9588 - mean_absolute_error: 0.0487 - accuracy: 0.9550 - val_loss: 0.2604 - val_cosine_similarity: 0.9470 - val_mean_absolute_error: 0.0810 - val_accuracy: 0.9505 - lr: 0.0010
# Epoch 5/50
# 599/599 [==============================] - 276s 461ms/step - loss: 0.1341 - cosine_similarity: 0.9592 - mean_absolute_error: 0.0487 - accuracy: 0.9552 - val_loss: 0.2640 - val_cosine_similarity: 0.9488 - val_mean_absolute_error: 0.0783 - val_accuracy: 0.9508 - lr: 0.0010
# Epoch 6/50
# 599/599 [==============================] - 274s 458ms/step - loss: 0.1282 - cosine_similarity: 0.9605 - mean_absolute_error: 0.0477 - accuracy: 0.9557 - val_loss: 0.2671 - val_cosine_similarity: 0.9483 - val_mean_absolute_error: 0.0720 - val_accuracy: 0.9505 - lr: 0.0010
# Epoch 7/50
# 599/599 [==============================] - 274s 458ms/step - loss: 0.1231 - cosine_similarity: 0.9609 - mean_absolute_error: 0.0476 - accuracy: 0.9558 - val_loss: 0.2588 - val_cosine_similarity: 0.9495 - val_mean_absolute_error: 0.0729 - val_accuracy: 0.9505 - lr: 0.0010
# Epoch 8/50
# 599/599 [==============================] - 277s 462ms/step - loss: 0.1207 - cosine_similarity: 0.9616 - mean_absolute_error: 0.0472 - accuracy: 0.9566 - val_loss: 0.2901 - val_cosine_similarity: 0.9415 - val_mean_absolute_error: 0.0954 - val_accuracy: 0.9449 - lr: 0.0010
# Epoch 9/50
# 599/599 [==============================] - ETA: 0s - loss: 0.1151 - cosine_similarity: 0.9628 - mean_absolute_error: 0.0463 - accuracy: 0.9575
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 599/599 [==============================] - 276s 461ms/step - loss: 0.1151 - cosine_similarity: 0.9628 - mean_absolute_error: 0.0463 - accuracy: 0.9575 - val_loss: 0.3132 - val_cosine_similarity: 0.9394 - val_mean_absolute_error: 0.1114 - val_accuracy: 0.9416 - lr: 0.0010
# Epoch 10/50
# 599/599 [==============================] - 276s 461ms/step - loss: 0.1042 - cosine_similarity: 0.9656 - mean_absolute_error: 0.0439 - accuracy: 0.9603 - val_loss: 0.2885 - val_cosine_similarity: 0.9461 - val_mean_absolute_error: 0.0807 - val_accuracy: 0.9490 - lr: 1.0000e-04
# Epoch 11/50
# 599/599 [==============================] - 276s 462ms/step - loss: 0.1013 - cosine_similarity: 0.9660 - mean_absolute_error: 0.0432 - accuracy: 0.9611 - val_loss: 0.2905 - val_cosine_similarity: 0.9468 - val_mean_absolute_error: 0.0775 - val_accuracy: 0.9491 - lr: 1.0000e-04
# Epoch 12/50
# 599/599 [==============================] - 276s 460ms/step - loss: 0.0997 - cosine_similarity: 0.9662 - mean_absolute_error: 0.0428 - accuracy: 0.9610 - val_loss: 0.2860 - val_cosine_similarity: 0.9474 - val_mean_absolute_error: 0.0773 - val_accuracy: 0.9499 - lr: 1.0000e-04
# Epoch 13/50
# 599/599 [==============================] - 276s 461ms/step - loss: 0.0988 - cosine_similarity: 0.9667 - mean_absolute_error: 0.0425 - accuracy: 0.9612 - val_loss: 0.2942 - val_cosine_similarity: 0.9463 - val_mean_absolute_error: 0.0802 - val_accuracy: 0.9495 - lr: 1.0000e-04
# Epoch 14/50
# 599/599 [==============================] - 276s 460ms/step - loss: 0.0975 - cosine_similarity: 0.9669 - mean_absolute_error: 0.0424 - accuracy: 0.9617 - val_loss: 0.2988 - val_cosine_similarity: 0.9466 - val_mean_absolute_error: 0.0775 - val_accuracy: 0.9492 - lr: 1.0000e-04
# Epoch 15/50
# 599/599 [==============================] - 275s 460ms/step - loss: 0.0965 - cosine_similarity: 0.9673 - mean_absolute_error: 0.0420 - accuracy: 0.9620 - val_loss: 0.2997 - val_cosine_similarity: 0.9445 - val_mean_absolute_error: 0.0869 - val_accuracy: 0.9485 - lr: 1.0000e-04
# Epoch 16/50
# 599/599 [==============================] - ETA: 0s - loss: 0.0954 - cosine_similarity: 0.9677 - mean_absolute_error: 0.0418 - accuracy: 0.9623
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 599/599 [==============================] - 275s 460ms/step - loss: 0.0954 - cosine_similarity: 0.9677 - mean_absolute_error: 0.0418 - accuracy: 0.9623 - val_loss: 0.2976 - val_cosine_similarity: 0.9461 - val_mean_absolute_error: 0.0800 - val_accuracy: 0.9495 - lr: 1.0000e-04
# Epoch 17/50
# 599/599 [==============================] - 276s 460ms/step - loss: 0.0935 - cosine_similarity: 0.9682 - mean_absolute_error: 0.0412 - accuracy: 0.9627 - val_loss: 0.3009 - val_cosine_similarity: 0.9454 - val_mean_absolute_error: 0.0817 - val_accuracy: 0.9491 - lr: 1.0000e-05
# Epoch 18/50
# 599/599 [==============================] - 275s 459ms/step - loss: 0.0932 - cosine_similarity: 0.9683 - mean_absolute_error: 0.0412 - accuracy: 0.9632 - val_loss: 0.3021 - val_cosine_similarity: 0.9455 - val_mean_absolute_error: 0.0811 - val_accuracy: 0.9493 - lr: 1.0000e-05
# Epoch 19/50
# 599/599 [==============================] - 275s 460ms/step - loss: 0.0930 - cosine_similarity: 0.9684 - mean_absolute_error: 0.0411 - accuracy: 0.9633 - val_loss: 0.3022 - val_cosine_similarity: 0.9454 - val_mean_absolute_error: 0.0813 - val_accuracy: 0.9493 - lr: 1.0000e-05
# Epoch 20/50
# 599/599 [==============================] - 275s 460ms/step - loss: 0.0929 - cosine_similarity: 0.9684 - mean_absolute_error: 0.0411 - accuracy: 0.9632 - val_loss: 0.3018 - val_cosine_similarity: 0.9456 - val_mean_absolute_error: 0.0811 - val_accuracy: 0.9494 - lr: 1.0000e-05
# Epoch 21/50
# 599/599 [==============================] - 275s 459ms/step - loss: 0.0928 - cosine_similarity: 0.9684 - mean_absolute_error: 0.0410 - accuracy: 0.9633 - val_loss: 0.3018 - val_cosine_similarity: 0.9459 - val_mean_absolute_error: 0.0797 - val_accuracy: 0.9494 - lr: 1.0000e-05
# Epoch 22/50
# 599/599 [==============================] - 275s 460ms/step - loss: 0.0926 - cosine_similarity: 0.9685 - mean_absolute_error: 0.0410 - accuracy: 0.9633 - val_loss: 0.3026 - val_cosine_similarity: 0.9457 - val_mean_absolute_error: 0.0803 - val_accuracy: 0.9494 - lr: 1.0000e-05
# Epoch 23/50
# 599/599 [==============================] - ETA: 0s - loss: 0.0926 - cosine_similarity: 0.9685 - mean_absolute_error: 0.0410 - accuracy: 0.9632
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 599/599 [==============================] - 275s 459ms/step - loss: 0.0926 - cosine_similarity: 0.9685 - mean_absolute_error: 0.0410 - accuracy: 0.9632 - val_loss: 0.3027 - val_cosine_similarity: 0.9459 - val_mean_absolute_error: 0.0795 - val_accuracy: 0.9493 - lr: 1.0000e-05
# Epoch 24/50
# 599/599 [==============================] - 275s 460ms/step - loss: 0.0922 - cosine_similarity: 0.9685 - mean_absolute_error: 0.0408 - accuracy: 0.9634 - val_loss: 0.3026 - val_cosine_similarity: 0.9459 - val_mean_absolute_error: 0.0796 - val_accuracy: 0.9494 - lr: 1.0000e-06
# Epoch 25/50
# 599/599 [==============================] - 275s 460ms/step - loss: 0.0923 - cosine_similarity: 0.9685 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3026 - val_cosine_similarity: 0.9458 - val_mean_absolute_error: 0.0800 - val_accuracy: 0.9493 - lr: 1.0000e-06
# Epoch 26/50
# 599/599 [==============================] - 275s 460ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0408 - accuracy: 0.9634 - val_loss: 0.3022 - val_cosine_similarity: 0.9458 - val_mean_absolute_error: 0.0799 - val_accuracy: 0.9494 - lr: 1.0000e-06
# Epoch 27/50
# 599/599 [==============================] - 275s 460ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0408 - accuracy: 0.9634 - val_loss: 0.3033 - val_cosine_similarity: 0.9456 - val_mean_absolute_error: 0.0802 - val_accuracy: 0.9492 - lr: 1.0000e-06
# Epoch 28/50
# 599/599 [==============================] - 275s 459ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9635 - val_loss: 0.3024 - val_cosine_similarity: 0.9459 - val_mean_absolute_error: 0.0799 - val_accuracy: 0.9495 - lr: 1.0000e-06
# Epoch 29/50
# 599/599 [==============================] - 275s 459ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3031 - val_cosine_similarity: 0.9457 - val_mean_absolute_error: 0.0800 - val_accuracy: 0.9493 - lr: 1.0000e-06
# Epoch 30/50
# 599/599 [==============================] - ETA: 0s - loss: 0.0921 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0408 - accuracy: 0.9635
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 599/599 [==============================] - 275s 460ms/step - loss: 0.0921 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0408 - accuracy: 0.9635 - val_loss: 0.3027 - val_cosine_similarity: 0.9458 - val_mean_absolute_error: 0.0800 - val_accuracy: 0.9494 - lr: 1.0000e-06
# Epoch 31/50
# 599/599 [==============================] - 275s 459ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3032 - val_cosine_similarity: 0.9457 - val_mean_absolute_error: 0.0800 - val_accuracy: 0.9493 - lr: 1.0000e-07
# Epoch 32/50
# 599/599 [==============================] - 282s 470ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3034 - val_cosine_similarity: 0.9456 - val_mean_absolute_error: 0.0802 - val_accuracy: 0.9493 - lr: 1.0000e-07
# Epoch 33/50
# 599/599 [==============================] - 280s 467ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3026 - val_cosine_similarity: 0.9459 - val_mean_absolute_error: 0.0799 - val_accuracy: 0.9495 - lr: 1.0000e-07
# Epoch 34/50
# 599/599 [==============================] - 282s 471ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3029 - val_cosine_similarity: 0.9458 - val_mean_absolute_error: 0.0799 - val_accuracy: 0.9495 - lr: 1.0000e-07
# Epoch 35/50
# 599/599 [==============================] - 282s 470ms/step - loss: 0.0921 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0408 - accuracy: 0.9634 - val_loss: 0.3034 - val_cosine_similarity: 0.9456 - val_mean_absolute_error: 0.0802 - val_accuracy: 0.9492 - lr: 1.0000e-07
# Epoch 36/50
# 599/599 [==============================] - 300s 500ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3020 - val_cosine_similarity: 0.9458 - val_mean_absolute_error: 0.0800 - val_accuracy: 0.9495 - lr: 1.0000e-07
# Epoch 37/50
# 599/599 [==============================] - ETA: 0s - loss: 0.0921 - cosine_similarity: 0.9687 - mean_absolute_error: 0.0408 - accuracy: 0.9635
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 599/599 [==============================] - 280s 467ms/step - loss: 0.0921 - cosine_similarity: 0.9687 - mean_absolute_error: 0.0408 - accuracy: 0.9635 - val_loss: 0.3032 - val_cosine_similarity: 0.9457 - val_mean_absolute_error: 0.0801 - val_accuracy: 0.9493 - lr: 1.0000e-07
# Epoch 38/50
# 599/599 [==============================] - 280s 468ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3034 - val_cosine_similarity: 0.9456 - val_mean_absolute_error: 0.0802 - val_accuracy: 0.9492 - lr: 1.0000e-08
# Epoch 39/50
# 599/599 [==============================] - 280s 467ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3026 - val_cosine_similarity: 0.9458 - val_mean_absolute_error: 0.0800 - val_accuracy: 0.9494 - lr: 1.0000e-08
# Epoch 40/50
# 599/599 [==============================] - 280s 467ms/step - loss: 0.0921 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0408 - accuracy: 0.9635 - val_loss: 0.3022 - val_cosine_similarity: 0.9458 - val_mean_absolute_error: 0.0800 - val_accuracy: 0.9495 - lr: 1.0000e-08
# Epoch 41/50
# 599/599 [==============================] - 280s 467ms/step - loss: 0.0920 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0408 - accuracy: 0.9635 - val_loss: 0.3035 - val_cosine_similarity: 0.9456 - val_mean_absolute_error: 0.0802 - val_accuracy: 0.9492 - lr: 1.0000e-08
# Epoch 42/50
# 599/599 [==============================] - 280s 467ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3032 - val_cosine_similarity: 0.9457 - val_mean_absolute_error: 0.0801 - val_accuracy: 0.9493 - lr: 1.0000e-08
# Epoch 43/50
# 599/599 [==============================] - 280s 468ms/step - loss: 0.0920 - cosine_similarity: 0.9687 - mean_absolute_error: 0.0408 - accuracy: 0.9635 - val_loss: 0.3034 - val_cosine_similarity: 0.9456 - val_mean_absolute_error: 0.0802 - val_accuracy: 0.9492 - lr: 1.0000e-08
# Epoch 44/50
# 599/599 [==============================] - ETA: 0s - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 599/599 [==============================] - 280s 467ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3032 - val_cosine_similarity: 0.9457 - val_mean_absolute_error: 0.0801 - val_accuracy: 0.9493 - lr: 1.0000e-08
# Epoch 45/50
# 599/599 [==============================] - 280s 467ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3034 - val_cosine_similarity: 0.9456 - val_mean_absolute_error: 0.0802 - val_accuracy: 0.9492 - lr: 1.0000e-09
# Epoch 46/50
# 599/599 [==============================] - 281s 468ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9635 - val_loss: 0.3029 - val_cosine_similarity: 0.9457 - val_mean_absolute_error: 0.0801 - val_accuracy: 0.9493 - lr: 1.0000e-09
# Epoch 47/50
# 599/599 [==============================] - 280s 468ms/step - loss: 0.0921 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0408 - accuracy: 0.9634 - val_loss: 0.3024 - val_cosine_similarity: 0.9459 - val_mean_absolute_error: 0.0799 - val_accuracy: 0.9496 - lr: 1.0000e-09
# Epoch 48/50
# 599/599 [==============================] - 280s 468ms/step - loss: 0.0921 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0408 - accuracy: 0.9635 - val_loss: 0.3026 - val_cosine_similarity: 0.9458 - val_mean_absolute_error: 0.0800 - val_accuracy: 0.9494 - lr: 1.0000e-09
# Epoch 49/50
# 599/599 [==============================] - 281s 469ms/step - loss: 0.0921 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0408 - accuracy: 0.9635 - val_loss: 0.3034 - val_cosine_similarity: 0.9456 - val_mean_absolute_error: 0.0802 - val_accuracy: 0.9492 - lr: 1.0000e-09
# Epoch 50/50
# 599/599 [==============================] - 280s 468ms/step - loss: 0.0922 - cosine_similarity: 0.9686 - mean_absolute_error: 0.0409 - accuracy: 0.9634 - val_loss: 0.3034 - val_cosine_similarity: 0.9456 - val_mean_absolute_error: 0.0802 - val_accuracy: 0.9492 - lr: 1.0000e-09

# %% [markdown]
# # END
