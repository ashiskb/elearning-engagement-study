# %%
import pickle
import matplotlib.pyplot as plt
import os
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
preprocessor_folder = 'gen-rnn-6'
source_location = 'drive/MyDrive/Colab Notebooks/DAiSEE/'+preprocessor_folder+'/Train/'

# %%
folder_info = os.listdir(source_location)
qty = len(folder_info)

random_sample_index = np.random.randint(0, qty)

sample_destination_filename = os.path.join(source_location + folder_info[random_sample_index])

filehandler = open(sample_destination_filename, 'rb') 
loaded_sample = pickle.load(filehandler)

desired_img_shape = (299,224)
w = 299
h = 224
fig = plt.figure(figsize=(8, 20))
columns = 2
rows = 5
for i in range(0, columns*rows):
    img = loaded_sample[i]
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(img)
plt.show()
