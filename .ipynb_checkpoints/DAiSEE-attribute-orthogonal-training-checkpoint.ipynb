# %% [markdown]
# # Purpose of this notebook:
# - Implement attribute-orthogonal multi-task training
# - Train a model for engagement grading with the DAiSEE dataset
#
# ### Status:
# - Multi-task training is implemented, but overfitting on the test set for gender
# - attribute-orthogonal loss still needs to be implemented

# %% [markdown]
# # Setup
# - This requires a folder structure similar to:
#
# parent directory<br>
# ├─this notebook<br>
# ├─/dataset<br>
# │  ├─/GenderClips<br>
# │  │  ├─Females<br>
# │  │  └─Males<br>
# │  ├─/Labels<br>
# │  ├─/Test<br>
# │  ├─/Train<br>
# │  └─/Validation<br>
# ├─/OUI gender dataset<br>
# │  └─/OUI_model.h5
#
# - Note: .gitignore includes the /dataset folder so that it can be co-located with the git repo for ease of use

# %% [markdown]
# # Sections
# [Model Configuration](#section1)<br />
# [Configure DAiSEE Sample Generators](#section2)<br />
# [Define Attribute Orthogonal Loss](#section3)<br />
# [Train Model](#section4)<br />

# %% [markdown]
# # Imports

# %%
#!pip install -r requirements.txt

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model

from tqdm import tqdm

import pandas as pd  # used for storing a tabular representation of the dataset, similar to XLS files.
from pathlib import Path # used to check if the saved model files and accessories.
import requests #used to request remote judge.csv evaluation 
from sklearn.preprocessing import StandardScaler  # used for normalization of dataset
from sklearn.preprocessing   import LabelBinarizer    # used for splitting the gender column
from sklearn.preprocessing   import MinMaxScaler      # used for normalization of dataset
from sklearn.model_selection import train_test_split  # used for performing the train-test split of a dataframe
import cv2                                            # OpenCV used for image processing
import random   #random number generator
import datetime #used to get current date/time
import math     #math/numerical functions
import os       #os specific functions, like file open/close etc.
import gc       #garbage collection module -- used to manually clean up memory spaces/references.

from sklearn.preprocessing import OneHotEncoder   #My favorite categorical to numerical feature conversion tool
from tensorflow import keras  # keras used for construction of the Artificial neural network
from keras.models import Model, Sequential #keras model architectures
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D #types of layers
from keras.losses import mean_squared_error, huber, log_cosh  #built-in loss 
from tensorflow.python.keras.saving import hdf5_format  #used for saving models 
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard  #callbacks
from keras.models import model_from_json  #used for loading model architecture from json file
import h5py  #saved model type

import matplotlib.pyplot as plt  # used for training visualization
import numpy as np  # numpy arrays used for matrix computations

from keras.applications import xception
from keras import backend as K
from keras.utils import np_utils

from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

# File handling imports
import shutil

# %%
# === Extra Configurations for the GPU Environment === #
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
if len(physical_devices)>0: #If you have at least one "configured" GPU, let's use it; otherwise, pass
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
print(f'Discovered devices: {physical_devices}')
# Out:
# Discovered devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#tf.config.experimental.set_memory_growth(physical_devices[0], False)
#device_spec = tf.DeviceSpec(job ="localhost", replica = 0, device_type = "CPU")

# %%
#print('Device Spec: ', device_spec.to_string())

# %%
# Disable eager execution
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %% [markdown]
# # References:
# - https://github.com/zaid478/Transfer-Learning-from-Xception-Model-in-Keras-/blob/master/transfer_learn.py

# %% [markdown]
# <a class="anchor" id="section1"></a>
# # Important Config

# %%
train_path = 'dataset/Train/'
test_path = 'dataset/Test/'
image_shape = (224, 299, 3) # HEIGHT, WIDTH, CHANNELS

# %% [markdown]
# # Import Model trained on OUI dataset

# %%
model_dir = "OUI gender dataset/"
model_name = 'OUI_model.h5'
OUI_model = load_model(os.path.join(model_dir, model_name))

# %%
OUI_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 299, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 111, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 111, 149, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 111, 149, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 109, 147, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 109, 147, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 109, 147, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 109, 147, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 109, 147, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 109, 147, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 109, 147, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 109, 147, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 55, 74, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 55, 74, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 55, 74, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 55, 74, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 55, 74, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 55, 74, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 55, 74, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 55, 74, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 55, 74, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 55, 74, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 28, 37, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 37, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 37, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 37, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 28, 37, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 28, 37, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#  block4_sepconv1_bn (BatchNorma  (None, 28, 37, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 28, 37, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 28, 37, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 28, 37, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 14, 19, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 19, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 14, 19, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 19, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 14, 19, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 14, 19, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 14, 19, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 14, 19, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 14, 19, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 14, 19, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 14, 19, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 14, 19, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 14, 19, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 14, 19, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 14, 19, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 14, 19, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 14, 19, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 14, 19, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 14, 19, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 14, 19, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 14, 19, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 14, 19, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 14, 19, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 14, 19, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 14, 19, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 14, 19, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 14, 19, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 14, 19, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 14, 19, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 14, 19, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 14, 19, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 14, 19, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 14, 19, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 14, 19, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 14, 19, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 14, 19, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 14, 19, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 14, 19, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#  block9_sepconv3_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 14, 19, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 14, 19, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 14, 19, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 14, 19, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 14, 19, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 14, 19, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 14, 19, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 14, 19, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 14, 19, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 14, 19, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 14, 19, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 14, 19, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 14, 19, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 14, 19, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 14, 19, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 14, 19, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 14, 19, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 14, 19, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 14, 19, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 14, 19, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 14, 19, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 14, 19, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 14, 19, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 14, 19, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 14, 19, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 14, 19, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 14, 19, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 7, 10, 1024)  745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 7, 10, 1024)  0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 10, 1024)  4096       ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 7, 10, 1024)  0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 7, 10, 1536)  1582080    ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 7, 10, 1536)  6144       ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 7, 10, 1536)  0          ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 7, 10, 2048)  3159552    ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 7, 10, 2048)  8192       ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 7, 10, 2048)  0          ['block14_sepconv2_bn[0][0]']
#  on)
#
#  global_max_pooling2d (GlobalMa  (None, 2048)        0           ['block14_sepconv2_act[0][0]']
#  xPooling2D)
#
#  layer_normalization (LayerNorm  (None, 2048)        4096        ['global_max_pooling2d[0][0]']
#  alization)
#
#  flatten (Flatten)              (None, 2048)         0           ['layer_normalization[0][0]']
#
#  d1 (Dense)                     (None, 512)          1049088     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['d1[0][0]']
#
#  d2 (Dense)                     (None, 512)          262656      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['d2[0][0]']
#
#  cls2_output (Dense)            (None, 2)            1026        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 22,178,346
# Trainable params: 1,316,866
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %%
# we'll need to reference the comparison layer
cls2a_layer = None
flatten_layer = None

# Freeze training on all layers
for layer in OUI_model.layers:
    layer.trainable = False
    
    # Get references to layers for functional API layer creation
    if layer.name == 'd1':
        cls2a_layer = layer
    elif layer.name == 'flatten':
        flatten_layer = layer
        
cls2a = cls2a_layer.output

# %% [markdown]
# # multi-task model references
# https://medium.com/swlh/multi-task-learning-with-tf-keras-5b28dd60246e <br>
# https://datascience.stackexchange.com/questions/27498/multi-task-learning-in-keras

# %%
flatten_layer.output
# Out:
# <tf.Tensor 'flatten/Reshape:0' shape=(None, 2048) dtype=float32>

# %%
x = flatten_layer.output

cls1a = Dense(
    512,
    activation='relu',
    name='d3',
    kernel_initializer=tf.keras.initializers.RandomNormal(mean=0., stddev=1.)
)(x)

x = Dropout(rate=0.25, name="dropout_3")(cls1a)

x = Dense(
    512,
    activation='relu',
    name='d4',
    kernel_initializer=tf.keras.initializers.RandomNormal(mean=0., stddev=1.)
)(x)

x = Dropout(rate=0.25, name="dropout_4")(x)

cls1_output = Dense(
    4,
    activation='softmax',
    name='cls1_output',
    kernel_initializer=tf.keras.initializers.RandomNormal(mean=0., stddev=1.)
)(x)

multitask_model=Model(inputs=OUI_model.input, outputs=[cls1_output, OUI_model.output])

# %%
multitask_model.output
# Out:
# [<tf.Tensor 'cls1_output/Softmax:0' shape=(None, 4) dtype=float32>,
#  <tf.Tensor 'cls2_output/Softmax:0' shape=(None, 2) dtype=float32>]

# %%
multitask_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 299, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 111, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 111, 149, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 111, 149, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 109, 147, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 109, 147, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 109, 147, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 109, 147, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 109, 147, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 109, 147, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 109, 147, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 109, 147, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 55, 74, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 55, 74, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 55, 74, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 55, 74, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 55, 74, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 55, 74, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 55, 74, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 55, 74, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 55, 74, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 55, 74, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 28, 37, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 37, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 37, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 37, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 28, 37, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 28, 37, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#  block4_sepconv1_bn (BatchNorma  (None, 28, 37, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 28, 37, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 28, 37, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 28, 37, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 14, 19, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 19, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 14, 19, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 19, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 14, 19, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 14, 19, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 14, 19, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 14, 19, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 14, 19, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 14, 19, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 14, 19, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 14, 19, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 14, 19, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 14, 19, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 14, 19, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 14, 19, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 14, 19, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 14, 19, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 14, 19, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 14, 19, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 14, 19, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 14, 19, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 14, 19, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 14, 19, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 14, 19, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 14, 19, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 14, 19, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 14, 19, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 14, 19, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 14, 19, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 14, 19, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 14, 19, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 14, 19, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 14, 19, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 14, 19, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 14, 19, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 14, 19, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 14, 19, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#  block9_sepconv3_bn (BatchNorma  (None, 14, 19, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 14, 19, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 14, 19, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 14, 19, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 14, 19, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 14, 19, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 14, 19, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 14, 19, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 14, 19, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 14, 19, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 14, 19, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 14, 19, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 14, 19, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 14, 19, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 14, 19, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 14, 19, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 14, 19, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 14, 19, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 14, 19, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 14, 19, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 14, 19, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 14, 19, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 14, 19, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 14, 19, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 14, 19, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 14, 19, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 14, 19, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 14, 19, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 14, 19, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 7, 10, 1024)  745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 7, 10, 1024)  0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 10, 1024)  4096       ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 7, 10, 1024)  0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 7, 10, 1536)  1582080    ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 7, 10, 1536)  6144       ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 7, 10, 1536)  0          ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 7, 10, 2048)  3159552    ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 7, 10, 2048)  8192       ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 7, 10, 2048)  0          ['block14_sepconv2_bn[0][0]']
#  on)
#
#  global_max_pooling2d (GlobalMa  (None, 2048)        0           ['block14_sepconv2_act[0][0]']
#  xPooling2D)
#
#  layer_normalization (LayerNorm  (None, 2048)        4096        ['global_max_pooling2d[0][0]']
#  alization)
#
#  flatten (Flatten)              (None, 2048)         0           ['layer_normalization[0][0]']
#
#  d3 (Dense)                     (None, 512)          1049088     ['flatten[0][0]']
#
#  d1 (Dense)                     (None, 512)          1049088     ['flatten[0][0]']
#
#  dropout_3 (Dropout)            (None, 512)          0           ['d3[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['d1[0][0]']
#
#  d4 (Dense)                     (None, 512)          262656      ['dropout_3[0][0]']
#
#  d2 (Dense)                     (None, 512)          262656      ['dropout[0][0]']
#
#  dropout_4 (Dropout)            (None, 512)          0           ['d4[0][0]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['d2[0][0]']
#  cls1_output (Dense)            (None, 4)            2052        ['dropout_4[0][0]']
#
#  cls2_output (Dense)            (None, 2)            1026        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 23,492,142
# Trainable params: 1,313,796
# Non-trainable params: 22,178,346
# __________________________________________________________________________________________________

# %%
cls1a
# Out:
# <tf.Tensor 'd3/Relu:0' shape=(None, 512) dtype=float32>

# %%
cls2a
# Out:
# <tf.Tensor 'd1/Relu:0' shape=(None, 512) dtype=float32>

# %% [markdown]
# <a class="anchor" id="section2"></a>
# # DAiSEE: Create labels list

# %%
#validation_dataset_location = './dataset/Validation'

labels = pd.read_csv(os.path.join(os.getcwd(), 'dataset', 'Labels', 'AllLabels.csv'))
females = pd.read_csv(os.path.join(os.getcwd(), 'dataset', 'GenderClips', 'Females'), header=None)
males = pd.read_csv(os.path.join(os.getcwd(), 'dataset', 'GenderClips', 'Males'), header=None)

females_list = [x[0] for x in females.values.tolist()]
males_list = [x[0] for x in males.values.tolist()]

# Add gender feature columns
labels['male'] = labels.apply(lambda x: x['ClipID'] in males_list, axis=1)
labels['female'] = labels.apply(lambda x: x['ClipID'] in females_list, axis=1)

# %%
labels
# Out:
#               ClipID  Boredom  Engagement  Confusion  Frustration    male  \
# 0     1100011002.avi        0           2          0             0   True
# 1     1100011003.avi        0           2          0             0   True
# 2     1100011004.avi        0           3          0             0   True
# 3     1100011005.avi        0           3          0             0   True
# 4     1100011006.avi        0           3          0             0   True
# ...              ...      ...         ...        ...           ...    ...
# 8920  9877360164.avi        1           3          0             0  False
# 8921  9877360165.avi        0           3          0             0  False
# 8922  9877360166.avi        1           3          0             2  False
# 8923  9877360168.avi        1           3          1             1  False
# 8924  9877360169.avi        0           1          0             0  False
#
#       female
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 8920    True
# 8921    True
# 8922    True
# 8923    True
# 8924    True
#
# [8925 rows x 7 columns]

# %%
testLabels = pd.read_csv(os.path.join(os.getcwd(), 'dataset', 'Labels', 'TestLabels.csv'))

# %%
labels['ClipID'].values.tolist()
# Out:
# ['1100011002.avi',
#  '1100011003.avi',
#  '1100011004.avi',
#  '1100011005.avi',
#  '1100011006.avi',
#  '1100011007.avi',
#  '1100011008.avi',
#  '1100011009.avi',
#  '1100011010.avi',
#  '1100011011.avi',
#  '1100011012.avi',
#  '1100011013.avi',
#  '1100011014.avi',
#  '1100011015.avi',
#  '1100011016.avi',
#  '1100011017.avi',
#  '1100011018.avi',
#  '1100011019.avi',
#  '1100011020.avi',
#  '1100011021.avi',
#  '1100011022.avi',
#  '1100011023.avi',
#  '1100011025.avi',
#  '1100011026.avi',
#  '1100011027.avi',
#  '1100011028.avi',
#  '1100011029.avi',
#  '1100011031.avi',
#  '1100011032.avi',
#  '1100011034.avi',
#  '1100011035.avi',
#  '1100011037.avi',
#  '1100011038.avi',
#  '1100011040.avi',
#  '1100011046.avi',
#  '1100011047.avi',
#  '1100011048.avi',
#  '1100011049.avi',
#  '1100011050.avi',
#  '1100011051.avi',
#  '1100011052.avi',
#  '1100011053.avi',
#  '1100011054.avi',
#  '1100011055.avi',
#  '1100011056.avi',
#  '1100011057.avi',
#  '1100011058.avi',
#  '1100011059.avi',
#  '1100011060.avi',
#  '1100011062.avi',
#  '1100011063.avi',
#  '1100011064.avi',
#  '1100011066.avi',
#  '1100011067.avi',
#  '1100011068.avi',
#  '1100011069.avi',
#  '1100011070.avi',
#  '1100011071.avi',
#  '1100011072.avi',
#  '1100011073.avi',
#  '1100011075.avi',
#  '1100011076.avi',
#  '1100011078.avi',
#  '1100011079.avi',
#  '1100011080.avi',
#  '1100011081.avi',
#  '1100011082.avi',
#  '1100011083.avi',
#  '1100012001.avi',
#  '1100012003.avi',
#  '1100012007.avi',
#  '1100012008.avi',
#  '1100012009.avi',
#  '1100012010.avi',
#  '1100012011.avi',
#  '1100012013.avi',
#  '1100012014.avi',
#  '1100012015.avi',
#  '1100012016.avi',
#  '1100012017.avi',
#  '1100012018.avi',
#  '1100012021.avi',
#  '1100012022.avi',
#  '1100012023.avi',
#  '1100012025.avi',
#  '1100012026.avi',
#  '1100012027.avi',
#  '1100012028.avi',
#  '1100012030.avi',
#  '1100012031.avi',
#  '1100012032.avi',
#  '1100012033.avi',
#  '1100012036.avi',
#  '1100012037.avi',
#  '1100012038.avi',
#  '1100012041.avi',
#  '1100012042.avi',
#  '1100012045.avi',
#  '1100012046.avi',
#  '1100012047.avi',
#  '1100012049.avi',
#  '1100012050.avi',
#  '1100012051.avi',
#  '1100012052.avi',
#  '1100012057.avi',
#  '1100012059.avi',
#  '1100012060.avi',
#  '1100012061.avi',
#  '1100012062.avi',
#  '1100012063.avi',
#  '1100012064.avi',
#  '1100012065.avi',
#  '1100012066.avi',
#  '1100012069.avi',
#  '1100021001.avi',
#  '1100021003.avi',
#  '1100021015.avi',
#  '1100021038.avi',
#  '1100021039.avi',
#  '1100021040.avi',
#  '1100021045.avi',
#  '1100021050.avi',
#  '1100021055.avi',
#  '1100022001.avi',
#  '1100022002.avi',
#  '1100022003.avi',
#  '1100022004.avi',
#  '1100022005.avi',
#  '1100022008.avi',
#  '1100022009.avi',
#  '1100022014.avi',
#  '1100022019.avi',
#  '1100022020.avi',
#  '1100022021.avi',
#  '1100022022.avi',
#  '1100022026.avi',
#  '1100022027.avi',
#  '1100022028.avi',
#  '1100022029.avi',
#  '1100022031.avi',
#  '1100022035.avi',
#  '1100022038.avi',
#  '1100022039.avi',
#  '1100022045.avi',
#  '1100022046.avi',
#  '1100022047.avi',
#  '1100022048.avi',
#  '1100022049.avi',
#  '1100022051.avi',
#  '1100022052.avi',
#  '1100022053.avi',
#  '1100022054.avi',
#  '1100022055.avi',
#  '1100022056.avi',
#  '1100022057.avi',
#  '1100041006.avi',
#  '1100041015.avi',
#  '1100041016.avi',
#  '1100041017.avi',
#  '1100041018.avi',
#  '1100041021.avi',
#  '1100041022.avi',
#  '1100041023.avi',
#  '1100041024.avi',
#  '1100041029.avi',
#  '1100041034.avi',
#  '1100041044.avi',
#  '1100041051.avi',
#  '1100041052.avi',
#  '1100042009.avi',
#  '1100042010.avi',
#  '1100042011.avi',
#  '1100042017.avi',
#  '1100042018.avi',
#  '1100042019.avi',
#  '1100042020.avi',
#  '1100042023.avi',
#  '1100042024.avi',
#  '1100042025.avi',
#  '1100042026.avi',
#  '1100042029.avi',
#  '1100042030.avi',
#  '1100042031.avi',
#  '1100042034.avi',
#  '1100042040.avi',
#  '1100042041.avi',
#  '1100042058.avi',
#  '1100042059.avi',
#  '1100042060.avi',
#  '1100051002.avi',
#  '1100051004.avi',
#  '1100051006.avi',
#  '1100051007.avi',
#  '1100051008.avi',
#  '1100051009.avi',
#  '1100051011.avi',
#  '1100051012.avi',
#  '1100051013.avi',
#  '1100051014.avi',
#  '1100051016.avi',
#  '1100051017.avi',
#  '1100051019.avi',
#  '1100051020.avi',
#  '1100051021.avi',
#  '1100051022.avi',
#  '1100051023.avi',
#  '1100051024.avi',
#  '1100051025.avi',
#  '1100051026.avi',
#  '1100051028.avi',
#  '1100051029.avi',
#  '1100051030.avi',
#  '1100051031.avi',
#  '1100051032.avi',
#  '1100051033.avi',
#  '1100051034.avi',
#  '1100051035.avi',
#  '1100051036.avi',
#  '1100051037.avi',
#  '1100051039.avi',
#  '1100051041.avi',
#  '1100051042.avi',
#  '1100051044.avi',
#  '1100051045.avi',
#  '1100051046.avi',
#  '1100051048.avi',
#  '1100051049.avi',
#  '1100051050.avi',
#  '1100051051.avi',
#  '1100051052.avi',
#  '1100051053.avi',
#  '1100051054.avi',
#  '1100051055.avi',
#  '1100051056.avi',
#  '1100051057.avi',
#  '1100051059.avi',
#  '1100051061.avi',
#  '1100051062.avi',
#  '1100051064.avi',
#  '1100051065.avi',
#  '1100051066.avi',
#  '1100051067.avi',
#  '1100051068.avi',
#  '1100051071.avi',
#  '1100051076.avi',
#  '1100051078.avi',
#  '1100051079.avi',
#  '1100052001.avi',
#  '1100052002.avi',
#  '1100052006.avi',
#  '1100052007.avi',
#  '1100052008.avi',
#  '1100052009.avi',
#  '1100052014.avi',
#  '1100052023.avi',
#  '1100052024.avi',
#  '1100052026.avi',
#  '1100052027.avi',
#  '1100052028.avi',
#  '1100052030.avi',
#  '1100052031.avi',
#  '1100052032.avi',
#  '1100052033.avi',
#  '1100052035.avi',
#  '1100052036.avi',
#  '1100052037.avi',
#  '1100052038.avi',
#  '1100052039.avi',
#  '1100052040.avi',
#  '1100052041.avi',
#  '1100052047.avi',
#  '1100052048.avi',
#  '1100052049.avi',
#  '1100052051.avi',
#  '1100052055.avi',
#  '1100052057.avi',
#  '1100052060.avi',
#  '1100052061.avi',
#  '1100052062.avi',
#  '1100052065.avi',
#  '1100052068.avi',
#  '1100052070.avi',
#  '1100061009.avi',
#  '1100061010.avi',
#  '1100061011.avi',
#  '1100061012.avi',
#  '1100061013.avi',
#  '1100061015.avi',
#  '1100061016.avi',
#  '1100061018.avi',
#  '1100061019.avi',
#  '1100061022.avi',
#  '1100061023.avi',
#  '1100061025.avi',
#  '1100061027.avi',
#  '1100061028.avi',
#  '1100061030.avi',
#  '1100061031.avi',
#  '1100061032.avi',
#  '1100061033.avi',
#  '1100061034.avi',
#  '1100061035.avi',
#  '1100061036.avi',
#  '1100061038.avi',
#  '1100061039.avi',
#  '1100061040.avi',
#  '1100061042.avi',
#  '1100061043.avi',
#  '1100061044.avi',
#  '1100061046.avi',
#  '1100061047.avi',
#  '1100061048.avi',
#  '1100061049.avi',
#  '1100061050.avi',
#  '1100061051.avi',
#  '1100061053.avi',
#  '1100061057.avi',
#  '1100061058.avi',
#  '1100061061.avi',
#  '1100061063.avi',
#  '1100061064.avi',
#  '1100061067.avi',
#  '1100061068.avi',
#  '1100061069.avi',
#  '1100061073.avi',
#  '1100061074.avi',
#  '1100061077.avi',
#  '1100061078.avi',
#  '1100062004.avi',
#  '1100062005.avi',
#  '1100062007.avi',
#  '1100062008.avi',
#  '1100062009.avi',
#  '1100062016.avi',
#  '1100062017.avi',
#  '1100062024.avi',
#  '1100062028.avi',
#  '1100062029.avi',
#  '1100062036.avi',
#  '1100062037.avi',
#  '1100062044.avi',
#  '1100062045.avi',
#  '1100062046.avi',
#  '1100062049.avi',
#  '1100062051.avi',
#  '1100062053.avi',
#  '1100062054.avi',
#  '1100062059.avi',
#  '1100062060.avi',
#  '1100062061.avi',
#  '1100062062.avi',
#  '1100062063.avi',
#  '1100062064.avi',
#  '1100062065.avi',
#  '1100062066.avi',
#  '1100062067.avi',
#  '1100062068.avi',
#  '1100062069.avi',
#  '1100062070.avi',
#  '1100062071.avi',
#  '1100062072.avi',
#  '1100071005.avi',
#  '1100071006.avi',
#  '1100071007.avi',
#  '1100071008.avi',
#  '1100071009.avi',
#  '1100071010.avi',
#  '1100071011.avi',
#  '1100071012.avi',
#  '1100071013.avi',
#  '1100071014.avi',
#  '1100071015.avi',
#  '1100071016.avi',
#  '1100071017.avi',
#  '1100071018.avi',
#  '1100071019.avi',
#  '1100071020.avi',
#  '1100071021.avi',
#  '1100071022.avi',
#  '1100071023.avi',
#  '1100071024.avi',
#  '1100071026.avi',
#  '1100071027.avi',
#  '1100071028.avi',
#  '1100071029.avi',
#  '1100071030.avi',
#  '1100071031.avi',
#  '1100071032.avi',
#  '1100071033.avi',
#  '1100071034.avi',
#  '1100071035.avi',
#  '1100071036.avi',
#  '1100071037.avi',
#  '1100071040.avi',
#  '1100071041.avi',
#  '1100071042.avi',
#  '1100071043.avi',
#  '1100071044.avi',
#  '1100071045.avi',
#  '1100071046.avi',
#  '1100071047.avi',
#  '1100071049.avi',
#  '1100071050.avi',
#  '1100071052.avi',
#  '1100071054.avi',
#  '1100071055.avi',
#  '1100071056.avi',
#  '1100071057.avi',
#  '1100071058.avi',
#  '1100071059.avi',
#  '1100071060.avi',
#  '1100071061.avi',
#  '1100071062.avi',
#  '1100071063.avi',
#  '1100071064.avi',
#  '1100071065.avi',
#  '1100071066.avi',
#  '1100071067.avi',
#  '1100071069.avi',
#  '1100071070.avi',
#  '1100071071.avi',
#  '1100071072.avi',
#  '1100071073.avi',
#  '1100071074.avi',
#  '1100071075.avi',
#  '1100071076.avi',
#  '1100071077.avi',
#  '1100071078.avi',
#  '1100071079.avi',
#  '1100071080.avi',
#  '1100071081.avi',
#  '1100072001.avi',
#  '1100072002.avi',
#  '1100072003.avi',
#  '1100072004.avi',
#  '1100072006.avi',
#  '1100072007.avi',
#  '1100072008.avi',
#  '1100072009.avi',
#  '1100072010.avi',
#  '1100072011.avi',
#  '1100072012.avi',
#  '1100072013.avi',
#  '1100072014.avi',
#  '1100072015.avi',
#  '1100072016.avi',
#  '1100072021.avi',
#  '1100072022.avi',
#  '1100072023.avi',
#  '1100072024.avi',
#  '1100072027.avi',
#  '1100072028.avi',
#  '1100072029.avi',
#  '1100072030.avi',
#  '1100072031.avi',
#  '1100072032.avi',
#  '1100072033.avi',
#  '1100072034.avi',
#  '1100072036.avi',
#  '1100072037.avi',
#  '1100072038.avi',
#  '1100072039.avi',
#  '1100072040.avi',
#  '1100072042.avi',
#  '1100072043.avi',
#  '1100072045.avi',
#  '1100072047.avi',
#  '1100072048.avi',
#  '1100072049.avi',
#  '1100072050.avi',
#  '1100072051.avi',
#  '1100072052.avi',
#  '1100072053.avi',
#  '1100072054.avi',
#  '1100072056.avi',
#  '1100072057.avi',
#  '1100072058.avi',
#  '1100072059.avi',
#  '1100072060.avi',
#  '1100072061.avi',
#  '1100072062.avi',
#  '1100072063.avi',
#  '1100072065.avi',
#  '1100072066.avi',
#  '1100072067.avi',
#  '1100072068.avi',
#  '1100072069.avi',
#  '1100072070.avi',
#  '1100072071.avi',
#  '1100072072.avi',
#  '1100072073.avi',
#  '1100072074.avi',
#  '1100072075.avi',
#  '1100072076.avi',
#  '1100072077.avi',
#  '1100072078.avi',
#  '1100072079.avi',
#  '1100072080.avi',
#  '1100072081.avi',
#  '1100072082.avi',
#  '1100072083.avi',
#  '1100072084.avi',
#  '1100072085.avi',
#  '1100081044.avi',
#  '1100081045.avi',
#  '1100081046.avi',
#  '1100081047.avi',
#  '1100081048.avi',
#  '1100082002.avi',
#  '1100082003.avi',
#  '1100082018.avi',
#  '1100082027.avi',
#  '1100102003.avi',
#  '1100111001.avi',
#  '1100111002.avi',
#  '1100111003.avi',
#  '1100111008.avi',
#  '1100111009.avi',
#  '1100111010.avi',
#  '1100111011.avi',
#  '1100111012.avi',
#  '1100111013.avi',
#  '1100111014.avi',
#  '1100111016.avi',
#  '1100111017.avi',
#  '1100111018.avi',
#  '1100111019.avi',
#  '1100111021.avi',
#  '1100111023.avi',
#  '1100111025.avi',
#  '1100111026.avi',
#  '1100111027.avi',
#  '1100111029.avi',
#  '1100111030.avi',
#  '1100111032.avi',
#  '1100112001.avi',
#  '1100112002.avi',
#  '1100112003.avi',
#  '1100112004.avi',
#  '1100112006.avi',
#  '1100112007.avi',
#  '1100112008.avi',
#  '1100112009.avi',
#  '1100112010.avi',
#  '1100112011.avi',
#  '1100112012.avi',
#  '1100112013.avi',
#  '1100112014.avi',
#  '1100112015.avi',
#  '1100112016.avi',
#  '1100112017.avi',
#  '1100112018.avi',
#  '1100112021.avi',
#  '1100112022.avi',
#  '1100112024.avi',
#  '1100112025.avi',
#  '1100112026.avi',
#  '1100112029.avi',
#  '1100112030.avi',
#  '1100112033.avi',
#  '1100112035.avi',
#  '1100112036.avi',
#  '1100112037.avi',
#  '1100112038.avi',
#  '1100112039.avi',
#  '1100112040.avi',
#  '1100112041.avi',
#  '1100112042.avi',
#  '1100112043.avi',
#  '1100112044.avi',
#  '1100112045.avi',
#  '1100112047.avi',
#  '1100112048.avi',
#  '1100112051.avi',
#  '1100112052.avi',
#  '1100112053.avi',
#  '1100112056.avi',
#  '1100112057.avi',
#  '1100112058.avi',
#  '1100112059.avi',
#  '1100112060.avi',
#  '1100112061.avi',
#  '1100112062.avi',
#  '1100112063.avi',
#  '1100112064.avi',
#  '1100112065.avi',
#  '1100112066.avi',
#  '1100112068.avi',
#  '1100121002.avi',
#  '1100121003.avi',
#  '1100121004.avi',
#  '1100121005.avi',
#  '1100121006.avi',
#  '1100121007.avi',
#  '1100121008.avi',
#  '1100121009.avi',
#  '1100121010.avi',
#  '1100121011.avi',
#  '1100121012.avi',
#  '1100121015.avi',
#  '1100121016.avi',
#  '1100121017.avi',
#  '1100121018.avi',
#  '1100121019.avi',
#  '1100121020.avi',
#  '1100121024.avi',
#  '1100121025.avi',
#  '1100121028.avi',
#  '1100121031.avi',
#  '1100121032.avi',
#  '1100121033.avi',
#  '1100121034.avi',
#  '1100121035.avi',
#  '1100121036.avi',
#  '1100121038.avi',
#  '1100121040.avi',
#  '1100121041.avi',
#  '1100121042.avi',
#  '1100121044.avi',
#  '1100121045.avi',
#  '1100121047.avi',
#  '1100121049.avi',
#  '1100121050.avi',
#  '1100121052.avi',
#  '1100121053.avi',
#  '1100121054.avi',
#  '1100121056.avi',
#  '1100121057.avi',
#  '1100121059.avi',
#  '1100121060.avi',
#  '1100121061.avi',
#  '1100121064.avi',
#  '1100122001.avi',
#  '1100122002.avi',
#  '1100122003.avi',
#  '1100122005.avi',
#  '1100122006.avi',
#  '1100122007.avi',
#  '1100122008.avi',
#  '1100122009.avi',
#  '1100122010.avi',
#  '1100122011.avi',
#  '1100122012.avi',
#  '1100122013.avi',
#  '1100122014.avi',
#  '1100122015.avi',
#  '1100122017.avi',
#  '1100122018.avi',
#  '1100122019.avi',
#  '1100122020.avi',
#  '1100122021.avi',
#  '1100122023.avi',
#  '1100122024.avi',
#  '1100122025.avi',
#  '1100122026.avi',
#  '1100122031.avi',
#  '1100122032.avi',
#  '1100122033.avi',
#  '1100122034.avi',
#  '1100122035.avi',
#  '1100122036.avi',
#  '1100122037.avi',
#  '1100122038.avi',
#  '1100122039.avi',
#  '1100122040.avi',
#  '1100122041.avi',
#  '1100122045.avi',
#  '1100122047.avi',
#  '1100122048.avi',
#  '1100122050.avi',
#  '1100122051.avi',
#  '1100122052.avi',
#  '1100122053.avi',
#  '1100122054.avi',
#  '1100122056.avi',
#  '1100131006.avi',
#  '1100131007.avi',
#  '1100131009.avi',
#  '1100131010.avi',
#  '1100131011.avi',
#  '1100131012.avi',
#  '1100131017.avi',
#  '1100131019.avi',
#  '1100141001.avi',
#  '1100141002.avi',
#  '1100141003.avi',
#  '1100141004.avi',
#  '1100141005.avi',
#  '1100141006.avi',
#  '1100141007.avi',
#  '1100141008.avi',
#  '1100141009.avi',
#  '1100141010.avi',
#  '1100141011.avi',
#  '1100141012.avi',
#  '1100141013.avi',
#  '1100141014.avi',
#  '1100141015.avi',
#  '1100141016.avi',
#  '1100141017.avi',
#  '1100141019.avi',
#  '1100141020.avi',
#  '1100141021.avi',
#  '1100141023.avi',
#  '1100141027.avi',
#  '1100141028.avi',
#  '1100141029.avi',
#  '1100141030.avi',
#  '1100141031.avi',
#  '1100141032.avi',
#  '1100141033.avi',
#  '1100141034.avi',
#  '1100141035.avi',
#  '1100141036.avi',
#  '1100141039.avi',
#  '1100141040.avi',
#  '1100141042.avi',
#  '1100141044.avi',
#  '1100141045.avi',
#  '1100141046.avi',
#  '1100141049.avi',
#  '1100141050.avi',
#  '1100141052.avi',
#  '1100141053.avi',
#  '1100141054.avi',
#  '1100141055.avi',
#  '1100141056.avi',
#  '1100141057.avi',
#  '1100142002.avi',
#  '1100142003.avi',
#  '1100142004.avi',
#  '1100142007.avi',
#  '1100142008.avi',
#  '1100142009.avi',
#  '1100142010.avi',
#  '1100142011.avi',
#  '1100142013.avi',
#  '1100142014.avi',
#  '1100142015.avi',
#  '1100142017.avi',
#  '1100142018.avi',
#  '1100142019.avi',
#  '1100142021.avi',
#  '1100142022.avi',
#  '1100142023.avi',
#  '1100142024.avi',
#  '1100142027.avi',
#  '1100142028.avi',
#  '1100142029.avi',
#  '1100142030.avi',
#  '1100142031.avi',
#  '1100142032.avi',
#  '1100142033.avi',
#  '1100142034.avi',
#  '1100142035.avi',
#  '1100142038.avi',
#  '1100142041.avi',
#  '1100142043.avi',
#  '1100142044.avi',
#  '1100142045.avi',
#  '1100142046.avi',
#  '1100142048.avi',
#  '1100142049.avi',
#  '1100142050.avi',
#  '1100142051.avi',
#  '1100142052.avi',
#  '1100142053.avi',
#  '1100142056.avi',
#  '1100142057.avi',
#  '1100142058.avi',
#  '1100142059.avi',
#  '1100142060.avi',
#  '1100151003.avi',
#  '1100151004.avi',
#  '1100151008.avi',
#  '1100151009.avi',
#  '1100151010.avi',
#  '1100151011.avi',
#  '1100151012.avi',
#  '1100151013.avi',
#  '1100151014.avi',
#  '1100151015.avi',
#  '1100151016.avi',
#  '1100151017.avi',
#  '1100151018.avi',
#  '1100151019.avi',
#  '1100151020.avi',
#  '1100151021.avi',
#  '1100151022.avi',
#  '1100151023.avi',
#  '1100151024.avi',
#  '1100151028.avi',
#  '1100151030.avi',
#  '1100151032.avi',
#  '1100151033.avi',
#  '1100151035.avi',
#  '1100151037.avi',
#  '1100151038.avi',
#  '1100151039.avi',
#  '1100151040.avi',
#  '1100151042.avi',
#  '1100151043.avi',
#  '1100151044.avi',
#  '1100151047.avi',
#  '1100151049.avi',
#  '1100151050.avi',
#  '1100151051.avi',
#  '1100151052.avi',
#  '1100151054.avi',
#  '1100151055.avi',
#  '1100151056.avi',
#  '1100151057.avi',
#  '1100151058.avi',
#  '1100151062.avi',
#  '1100152001.avi',
#  '1100152004.avi',
#  '1100152005.avi',
#  '1100152006.avi',
#  '1100152008.avi',
#  '1100152009.avi',
#  '1100152010.avi',
#  '1100152013.avi',
#  '1100152014.avi',
#  '1100152015.avi',
#  '1100152017.avi',
#  '1100152019.avi',
#  '1100152020.avi',
#  '1100152022.avi',
#  '1100152024.avi',
#  '1100152025.avi',
#  '1100152026.avi',
#  '1100152027.avi',
#  '1100152031.avi',
#  '1100152032.avi',
#  '1100152039.avi',
#  '1100152040.avi',
#  '1100152041.avi',
#  '1100152042.avi',
#  '1100152043.avi',
#  '1100152048.avi',
#  '1100152049.avi',
#  '1100152050.avi',
#  '1100152051.avi',
#  '1100152055.avi',
#  '1100152056.avi',
#  '1100152061.avi',
#  '1100152062.avi',
#  '1100152067.avi',
#  '1100152069.avi',
#  '1100152070.avi',
#  '1100161002.avi',
#  '1100161004.avi',
#  '1100161011.avi',
#  '1100161012.avi',
#  '1100161013.avi',
#  '1100161014.avi',
#  '1100161015.avi',
#  '1100161016.avi',
#  '1100161020.avi',
#  '1100161021.avi',
#  '1100161022.avi',
#  '1100161023.avi',
#  '1100161028.avi',
#  '1100161029.avi',
#  '1100161032.avi',
#  '1100161035.avi',
#  '1100161036.avi',
#  '1100161038.avi',
#  '1100161039.avi',
#  '1100161041.avi',
#  '1100161043.avi',
#  '1100161044.avi',
#  '1100161045.avi',
#  '1100161046.avi',
#  '1100161048.avi',
#  '1100161050.avi',
#  '1100161053.avi',
#  '1100162005.avi',
#  '1100162007.avi',
#  '1100162011.avi',
#  '1100162016.avi',
#  '1100171001.avi',
#  '1100171002.avi',
#  '1100171004.avi',
#  '1100171005.avi',
#  '1100171007.avi',
#  '1100171008.avi',
#  '1100171009.avi',
#  '1100171010.avi',
#  '1100171011.avi',
#  '1100171012.avi',
#  '1100171013.avi',
#  '1100171015.avi',
#  '1100171016.avi',
#  '1100171017.avi',
#  '1100171019.avi',
#  '1100171021.avi',
#  '1100171022.avi',
#  '1100171023.avi',
#  '1100171031.avi',
#  '1100171035.avi',
#  '1100171036.avi',
#  '1100171038.avi',
#  '1100171039.avi',
#  '1100171040.avi',
#  '1100171041.avi',
#  '1100171043.avi',
#  '1100171045.avi',
#  '1100171049.avi',
#  '1100171055.avi',
#  '1100171056.avi',
#  '1100171057.avi',
#  '1100171059.avi',
#  '1100171061.avi',
#  '1100171063.avi',
#  '1100171064.avi',
#  '1100171065.avi',
#  '1100171067.avi',
#  '1100171069.avi',
#  '1100171070.avi',
#  '1100171071.avi',
#  '1100171072.avi',
#  '1100171073.avi',
#  '1100171074.avi',
#  '1100171075.avi',
#  '1100171076.avi',
#  '1100171077.avi',
#  '1100171078.avi',
#  '1100171080.avi',
#  '1100171083.avi',
#  '1100172003.avi',
#  '1100172004.avi',
#  '1100172007.avi',
#  '1100172012.avi',
#  '1100172013.avi',
#  '1100172014.avi',
#  '1100172015.avi',
#  '1100172016.avi',
#  '1100172017.avi',
#  '1100172018.avi',
#  '1100172020.avi',
#  '1100172021.avi',
#  '1100172022.avi',
#  '1100172026.avi',
#  '1100172028.avi',
#  '1100172030.avi',
#  '1100172032.avi',
#  '1100172033.avi',
#  '1100172034.avi',
#  '1100172035.avi',
#  '1100172037.avi',
#  '1100172039.avi',
#  '1100172042.avi',
#  '1100172043.avi',
#  '1100172047.avi',
#  '1100172050.avi',
#  '1100172058.avi',
#  '1100172063.avi',
#  '1100172066.avi',
#  '1100411010.avi',
#  '1100411011.avi',
#  '1100411012.avi',
#  '1100411013.avi',
#  '1100411015.avi',
#  '1100411016.avi',
#  '1100411018.avi',
#  '1100411020.avi',
#  '1100411023.avi',
#  '1100411036.avi',
#  '1100411041.avi',
#  '1100411045.avi',
#  '1100411047.avi',
#  '1100411048.avi',
#  '1100411049.avi',
#  '1100411050.avi',
#  '1100411051.avi',
#  '1100411053.avi',
#  '1100411054.avi',
#  '1100411055.avi',
#  '1100411057.avi',
#  '1100412001.avi',
#  '1100412003.avi',
#  '1100412010.avi',
#  '1100412018.avi',
#  '1100412033.avi',
#  '1100412038.avi',
#  '1100412039.avi',
#  '1100412040.avi',
#  '1110031003.avi',
#  '1110031007.avi',
#  '1110031010.avi',
#  '1110031011.avi',
#  '1110031012.avi',
#  '1110031014.avi',
#  '1110031019.avi',
#  '1110031020.avi',
#  '1110031021.avi',
#  '1110031025.avi',
#  '1110031027.avi',
#  '1110031031.avi',
#  ...]

# %%
missing = len(set(testLabels['ClipID'].values.tolist()) - set(labels['ClipID'].values.tolist()))
print(f'There are {missing} samples without labels!')
# Out:
# There are 61 samples without labels!

# %%
labels['ID_num'] = labels['ClipID'].str[:-4]

# %%
# we want to make sure that there is a binary constraint
assert labels.loc[labels['male']!=labels['female']].shape == labels.shape

# %%
# Create a single column for gender
labels['gender'] = labels.apply(lambda x: 1 if x['ClipID'] in males_list else 0, axis=1)

# %%
labels.columns
# Out:
# Index(['ClipID', 'Boredom', 'Engagement', 'Confusion', 'Frustration ', 'male',
#        'female', 'ID_num', 'gender'],
#       dtype='object')

# %%
labels.drop(['male', 'female'], axis=1, inplace=True)

# %%
# We're only concerned with engagement
labels.drop(['Boredom', 'Confusion', 'Frustration '], axis=1, inplace=True)

# %%
labels['Engagement']
# Out:
# 0       2
# 1       2
# 2       3
# 3       3
# 4       3
#        ..
# 8920    3
# 8921    3
# 8922    3
# 8923    3
# 8924    1
# Name: Engagement, Length: 8925, dtype: int64

# %%
labels_ohe = pd.get_dummies(labels.Engagement)

# %%
labels_ohe.head()
# Out:
#    0  1  2  3
# 0  0  0  1  0
# 1  0  0  1  0
# 2  0  0  0  1
# 3  0  0  0  1
# 4  0  0  0  1

# %%
labels_ohe['tensor'] = labels_ohe.apply(lambda x: np.array([x[0], x[1], x[2], x[3]]), axis=1)

# %%
labels_ohe
# Out:
#       0  1  2  3        tensor
# 0     0  0  1  0  [0, 0, 1, 0]
# 1     0  0  1  0  [0, 0, 1, 0]
# 2     0  0  0  1  [0, 0, 0, 1]
# 3     0  0  0  1  [0, 0, 0, 1]
# 4     0  0  0  1  [0, 0, 0, 1]
# ...  .. .. .. ..           ...
# 8920  0  0  0  1  [0, 0, 0, 1]
# 8921  0  0  0  1  [0, 0, 0, 1]
# 8922  0  0  0  1  [0, 0, 0, 1]
# 8923  0  0  0  1  [0, 0, 0, 1]
# 8924  0  1  0  0  [0, 1, 0, 0]
#
# [8925 rows x 5 columns]

# %%
labels = labels.join(labels_ohe['tensor'])

# %%
labels.drop(['Engagement'], axis=1, inplace=True)
labels.drop(['ClipID'], axis=1, inplace=True)

# %%
labels.head()
# Out:
#        ID_num  gender        tensor
# 0  1100011002       1  [0, 0, 1, 0]
# 1  1100011003       1  [0, 0, 1, 0]
# 2  1100011004       1  [0, 0, 0, 1]
# 3  1100011005       1  [0, 0, 0, 1]
# 4  1100011006       1  [0, 0, 0, 1]

# %%
print("building training set")
missing_count = 0
train_set = []
for filename in tqdm(os.listdir(train_path)):
    try:
        sample_ID = filename[:filename.index('-')]
        #engagement = labels[labels['ID_num']==sample_ID].values.tolist()[0][1:-1]
        #gender = labels[labels['ID_num']==sample_ID].values.tolist()[1]
        row = labels[labels['ID_num']==sample_ID]
        engagement = row['tensor'].values[0]
        gender = row['gender'].values[0]
        train_set.append([filename, engagement, gender])
    except IndexError:
        missing_count += 1
print(f'There are {missing_count} samples without labels!')
# Out:
# building training set
# 100%|███████████████████████████████████████████████████████████████████████| 38374/38374 [00:27<00:00, 1406.98it/s]
# There are 0 samples without labels!

# %%
print("building test set")
missing_count = 0
test_set = []
for filename in tqdm(os.listdir(test_path)):
    try:
        sample_ID = filename[:filename.index('-')]
        #engagement = labels[labels['ID_num']==sample_ID].values.tolist()[0][1:-1]
        #gender = labels[labels['ID_num']==sample_ID].values.tolist()[1]
        row = labels[labels['ID_num']==sample_ID]
        engagement = row['tensor'].values[0]
        gender = row['gender'].values[0]
        test_set.append([filename, engagement, gender])
    except IndexError:
        missing_count += 1
print(f'There are {missing_count} samples without labels!')
# Out:
# building test set
# 100%|███████████████████████████████████████████████████████████████████████| 13062/13062 [00:09<00:00, 1401.51it/s]
# There are 1001 samples without labels!

# %%
train_df = pd.DataFrame(train_set, columns=['filename', 'engagement', 'gender'])

# %%
test_df = pd.DataFrame(test_set, columns=['filename', 'engagement', 'gender'])

# %%
train_df.describe()
# Out:
#              gender
# count  38374.000000
# mean       0.682050
# std        0.465686
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
train_df.head()
# Out:
#            filename    engagement  gender
# 0  1100011002-1.jpg  [0, 0, 1, 0]       1
# 1  1100011002-2.jpg  [0, 0, 1, 0]       1
# 2  1100011002-3.jpg  [0, 0, 1, 0]       1
# 3  1100011002-4.jpg  [0, 0, 1, 0]       1
# 4  1100011002-5.jpg  [0, 0, 1, 0]       1

# %%
test_df.describe()
# Out:
#              gender
# count  12061.000000
# mean       0.755078
# std        0.430059
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# # ImageDataGenerator
# - https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator
# - https://studymachinelearning.com/keras-imagedatagenerator-with-flow_from_dataframe/
# - https://stackoverflow.com/questions/60621008/imagedatagenerator-for-multi-task-output-in-keras-using-flow-from-directory

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.xception.preprocess_input
)

# %%
training_generator = image_generator.flow_from_dataframe(
    dataframe=train_df,
    directory=train_path,
    x_col="filename",
    y_col=["engagement", "gender"],
    batch_size=32,
    shuffle=True,
    seed=42,
    class_mode='multi_output',
    target_size=(image_shape[0], image_shape[1])
)
# Out:
# Found 38374 validated image filenames.

# %%
validation_generator = image_generator.flow_from_dataframe(
    dataframe=test_df,
    directory=test_path,
    x_col="filename",
    y_col=["engagement", "gender"],
    batch_size=32,
    shuffle=True,
    seed=42,
    class_mode='multi_output',
    target_size=(image_shape[0], image_shape[1])
)
# Out:
# Found 12061 validated image filenames.

# %%
image_shape
# Out:
# (224, 299, 3)

# %%
validation_generator[0][0].shape
# Out:
# (32, 224, 299, 3)

# %% [markdown]
# <a class="anchor" id="section3"></a>
# # Implement Attribute Orthogonal Regularized Loss

# %%
# Reference the tensors created by layers
cls1 = cls1a
cls2 = cls2a

def orthogonal_loss(y_true, y_pred, alpha=1):
    # requires cls1, cls2 layers to be defined through functional API
    cls1_cls2 = tf.linalg.matmul(cls1, cls2, transpose_b=True)
    numerator = tf.norm(cls1_cls2, ord=1)
    cls1_norm = tf.norm(cls1, ord=2)
    cls2_norm = tf.norm(cls2, ord=2)
    denominator = tf.math.multiply(cls1_norm, cls2_norm)
    loss_ortho = tf.math.divide_no_nan(numerator, denominator)
    
    loss_categorical = keras.losses.categorical_crossentropy(y_true, y_pred)
    
    return loss_categorical + alpha * loss_ortho
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 # Reference the tensors created by layers
# ----> 2 cls1 = cls1a
#       3 cls2 = cls2a
#       5 def orthogonal_loss(y_true, y_pred, alpha=1):
#       6     # requires cls1, cls2 layers to be defined through functional API
#
# NameError: name 'cls1a' is not defined

# %% [markdown]
# <a class="anchor" id="section4"></a>
# # Set up for training

# %%
# %reload_ext tensorboard
model_path = os.path.join('saved_models/model_' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '_.sav')
log_dir = os.path.join("logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

monitor_accuracy = 'val_cls1_output_accuracy'
monitor_mae = 'val_cls1_output_mean_absolute_error'
monitor_loss = 'val_cls1_output_loss'

# monitor_accuracy = 'val_accuracy'
# monitor_mae = 'val_mean_absolute_error'
# monitor_loss = 'val_loss'

tensorboard_cbk = TensorBoard(log_dir=log_dir, histogram_freq=1)
early_stopping_cbk = EarlyStopping(monitor=monitor_accuracy, patience=10, verbose=0, mode='max')
mcp_save_cbk = ModelCheckpoint(model_path+'.mcp.hdf5', save_best_only=True, monitor=monitor_accuracy, mode='max')
reduce_lr_plateau_cbk = ReduceLROnPlateau(monitor=monitor_loss, factor=0.1, patience=7, verbose=1, mode='min')
callbacks = [early_stopping_cbk, mcp_save_cbk, reduce_lr_plateau_cbk, tensorboard_cbk]

# %%
losses = {
    'cls1_output': orthogonal_loss,
    #'cls1_output': tf.keras.losses.CategoricalCrossentropy(),
    'cls2_output': tf.keras.losses.SparseCategoricalCrossentropy()
    #'cls2_output': 'sparse_categorical_crossentropy'
}

# Turn off weights for gender classifier... we are only training engagement classifier
lossWeights = {"cls1_output": 1.0, "cls2_output": 0.00001}

# %%
multitask_model.compile(
    loss = losses,
    loss_weights=lossWeights,
    optimizer='adam',
    metrics = ['accuracy']
)

# %%
history = multitask_model.fit(
    training_generator,
    validation_data=validation_generator,
    #batch_size=64,
    epochs=50,
    #steps_per_epoch=10, # Set temporarily for frequent validation
    #validation_steps = 1,
    #callbacks=callbacks)
    callbacks=[early_stopping_cbk, mcp_save_cbk, reduce_lr_plateau_cbk]
)
# Out:
# Epoch 1/50
# 1200/1200 [==============================] - ETA: 0s - batch: 599.5000 - size: 31.9783 - loss: 2710.5580 - cls1_output_loss: 2710.5569 - cls2_output_loss: 107.4308 - cls1_output_accuracy: 0.5209 - cls2_output_accuracy: 0.7969
# C:\Users\netwo\anaconda3\envs\Thesis-minimum\lib\site-packages\keras\engine\training_v1.py:2332: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 1200/1200 [==============================] - 464s 385ms/step - batch: 599.5000 - size: 31.9783 - loss: 2710.5560 - cls1_output_loss: 2710.5569 - cls2_output_loss: 107.4308 - cls1_output_accuracy: 0.5209 - cls2_output_accuracy: 0.7969 - val_loss: 1236.4082 - val_cls1_output_loss: 1236.4077 - val_cls2_output_loss: 33.0183 - val_cls1_output_accuracy: 0.5448 - val_cls2_output_accuracy: 0.8960 - lr: 0.0010
# Epoch 2/50
# 1200/1200 [==============================] - 453s 377ms/step - batch: 599.5000 - size: 31.9783 - loss: 868.2325 - cls1_output_loss: 868.2319 - cls2_output_loss: 108.7868 - cls1_output_accuracy: 0.5471 - cls2_output_accuracy: 0.7936 - val_loss: 730.6757 - val_cls1_output_loss: 730.6757 - val_cls2_output_loss: 33.0059 - val_cls1_output_accuracy: 0.5392 - val_cls2_output_accuracy: 0.8960 - lr: 0.0010
# Epoch 3/50
# 1200/1200 [==============================] - 452s 377ms/step - batch: 599.5000 - size: 31.9783 - loss: 444.8654 - cls1_output_loss: 444.8646 - cls2_output_loss: 108.5982 - cls1_output_accuracy: 0.5518 - cls2_output_accuracy: 0.7961 - val_loss: 541.9395 - val_cls1_output_loss: 541.9393 - val_cls2_output_loss: 33.0133 - val_cls1_output_accuracy: 0.5317 - val_cls2_output_accuracy: 0.8960 - lr: 0.0010
# Epoch 4/50
# 1200/1200 [==============================] - 452s 377ms/step - batch: 599.5000 - size: 31.9783 - loss: 234.2864 - cls1_output_loss: 234.2853 - cls2_output_loss: 105.5970 - cls1_output_accuracy: 0.5460 - cls2_output_accuracy: 0.7982 - val_loss: 410.6507 - val_cls1_output_loss: 410.6505 - val_cls2_output_loss: 33.0128 - val_cls1_output_accuracy: 0.5208 - val_cls2_output_accuracy: 0.8960 - lr: 0.0010
# Epoch 5/50
# 1200/1200 [==============================] - 452s 377ms/step - batch: 599.5000 - size: 31.9783 - loss: 106.3620 - cls1_output_loss: 106.3609 - cls2_output_loss: 107.4804 - cls1_output_accuracy: 0.5390 - cls2_output_accuracy: 0.7946 - val_loss: 270.2554 - val_cls1_output_loss: 270.2553 - val_cls2_output_loss: 33.0105 - val_cls1_output_accuracy: 0.5029 - val_cls2_output_accuracy: 0.8960 - lr: 0.0010
# Epoch 6/50
# 1200/1200 [==============================] - 452s 377ms/step - batch: 599.5000 - size: 31.9783 - loss: 50.9535 - cls1_output_loss: 50.9524 - cls2_output_loss: 109.8658 - cls1_output_accuracy: 0.5335 - cls2_output_accuracy: 0.7955 - val_loss: 222.7815 - val_cls1_output_loss: 222.7811 - val_cls2_output_loss: 33.0111 - val_cls1_output_accuracy: 0.4971 - val_cls2_output_accuracy: 0.8960 - lr: 0.0010
# Epoch 7/50
# 1200/1200 [==============================] - 452s 377ms/step - batch: 599.5000 - size: 31.9783 - loss: 24.6643 - cls1_output_loss: 24.6633 - cls2_output_loss: 106.5587 - cls1_output_accuracy: 0.5176 - cls2_output_accuracy: 0.7970 - val_loss: 148.4739 - val_cls1_output_loss: 148.4736 - val_cls2_output_loss: 33.0113 - val_cls1_output_accuracy: 0.4852 - val_cls2_output_accuracy: 0.8960 - lr: 0.0010
# Epoch 8/50
# 1200/1200 [==============================] - 452s 377ms/step - batch: 599.5000 - size: 31.9783 - loss: 11.4948 - cls1_output_loss: 11.4937 - cls2_output_loss: 107.5521 - cls1_output_accuracy: 0.5003 - cls2_output_accuracy: 0.7950 - val_loss: 115.3945 - val_cls1_output_loss: 115.3941 - val_cls2_output_loss: 33.0067 - val_cls1_output_accuracy: 0.4917 - val_cls2_output_accuracy: 0.8960 - lr: 0.0010
# Epoch 9/50
# 1200/1200 [==============================] - 452s 377ms/step - batch: 599.5000 - size: 31.9783 - loss: 5.6784 - cls1_output_loss: 5.6773 - cls2_output_loss: 107.2118 - cls1_output_accuracy: 0.4950 - cls2_output_accuracy: 0.7987 - val_loss: 110.0179 - val_cls1_output_loss: 110.0176 - val_cls2_output_loss: 33.0165 - val_cls1_output_accuracy: 0.4933 - val_cls2_output_accuracy: 0.8960 - lr: 0.0010
# Epoch 10/50
# 1200/1200 [==============================] - 452s 377ms/step - batch: 599.5000 - size: 31.9783 - loss: 3.6920 - cls1_output_loss: 3.6909 - cls2_output_loss: 105.0136 - cls1_output_accuracy: 0.4934 - cls2_output_accuracy: 0.7987 - val_loss: 86.2278 - val_cls1_output_loss: 86.2274 - val_cls2_output_loss: 33.0196 - val_cls1_output_accuracy: 0.4927 - val_cls2_output_accuracy: 0.8960 - lr: 0.0010
# Epoch 11/50
# 1200/1200 [==============================] - 452s 377ms/step - batch: 599.5000 - size: 31.9783 - loss: 3.0550 - cls1_output_loss: 3.0540 - cls2_output_loss: 107.4368 - cls1_output_accuracy: 0.4855 - cls2_output_accuracy: 0.7962 - val_loss: 75.8570 - val_cls1_output_loss: 75.8567 - val_cls2_output_loss: 33.0103 - val_cls1_output_accuracy: 0.4848 - val_cls2_output_accuracy: 0.8960 - lr: 0.0010

# %%
filename = 'DAiSEE-AOR-model_1.h5'
#multitask_model.save(filename)

# %% [markdown]
# # END
