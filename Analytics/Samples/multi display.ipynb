# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np

im1 = np.arange(100).reshape((10, 10))
im2 = im1.T
im3 = np.flipud(im1)
im4 = np.fliplr(im2)

fig = plt.figure(figsize=(4., 4.))

grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(2, 2),  # creates 2x2 grid of axes
                 axes_pad=0.1,  # pad between axes in inch.
                 )

for ax, im in zip(grid, [im1, im2, im3, im4]):
    # Iterating over the grid returns the Axes.
    ax.get_yaxis().set_visible(False)
    ax.get_xaxis().set_visible(False)
    ax.imshow(im)
 
plt.show()

# %%
import os

# %%
import PIL

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Engagement 0',
#  'Engagement 1',
#  'Engagement 2',
#  'Engagement 3',
#  'Untitled.ipynb']

# %%
folders = [
    'Engagement 0',
    'Engagement 1',
    'Engagement 2',
    'Engagement 3',
]

all_images = []
for folder in folders:
    set_images = []
    images = os.listdir(folder)
    for image in images:
        set_images.append(PIL.Image.open(os.path.join(folder, image)))
    all_images.append(set_images)

# %%
all_images
# Out:
# [[<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD956B60>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD954580>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD9543A0>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DB77FDF0>],
#  [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DB77E230>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD752290>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD751A80>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD751840>],
#  [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD751930>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD750CA0>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD751540>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD751F60>],
#  [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD752EF0>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD752F20>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD751000>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x224 at 0x193DD7527A0>]]

# %%
fig = plt.figure(figsize=(15., 15.))

grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(4, 4),
                 axes_pad=0.1,  # pad between axes in inch.
                 )

for ax, im in zip(grid, [img for imgs in all_images for img in imgs]):
    # Iterating over the grid returns the Axes.
    ax.get_yaxis().set_visible(False)
    ax.get_xaxis().set_visible(False)
    ax.imshow(im)
 
plt.show()
